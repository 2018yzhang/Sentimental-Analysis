# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
nltk.downloader.download('vader_lexicon')
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/yidanzhang/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import os
import pandas as pd
from flask import Flask, jsonify, request
import json
import requests
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
app = Flask(__name__)


@app.route('/doAnalysis')
def analysis():
    url = ''
# Out:
#   File "/var/folders/_7/4khzbbcd43l_vh28c2hw7l7w0000gn/T/ipykernel_98016/902721815.py", line 4
#     @app.route('/readNews')
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
bitpush_news = pd.read_csv("data - news.csv")
bitpush_news.head()
# Out:
#                                                Title  \
# 0         Why is Shiba Inu Up 200% in the Past Week?
# 1  What are the Most Promising Projects Building ...
# 2  Bitpush Research Paper: The Impact of Media an...
# 3           Why are there still no dApps on Cardano?
# 4  What is the NFT Project ‘Loot’ and How Valuabl...
#
#                                              Content  \
# 0  In the past few weeks, the cryptocurrency mark...
# 1  With the recent launch of smart contracts, the...
# 2  Introduction:Since its inception of 2008, Bitc...
# 3  Now that Cardano has finally released smart co...
# 4  Loot is an NFT project that is taking the cryp...
#
#                                         Url        Time        Emotion
# 0  https://en.bitpush.news/articles/3660343  1633878038  偏0 甚至negative
# 1  https://en.bitpush.news/articles/3631214  1632387709              1
# 2  https://en.bitpush.news/articles/3627662  1632228330              1
# 3  https://en.bitpush.news/articles/3625850  1632153530             -1
# 4  https://en.bitpush.news/articles/3615932  1631648672              1

# %%
vader = SentimentIntensityAnalyzer()
content = bitpush_news['Content']
content = str(content).encode('utf-8')
content_scores = bitpush_news['Content'].apply(lambda content:vader.polarity_scores(content)).tolist()
content_scores_df = pd.DataFrame(content_scores)
content_scores_df
# Out:
#       neg    neu    pos  compound
# 0   0.040  0.868  0.092    0.9826
# 1   0.007  0.853  0.140    0.9982
# 2   0.029  0.879  0.092    0.9986
# 3   0.038  0.853  0.109    0.9959
# 4   0.029  0.865  0.106    0.9919
# ..    ...    ...    ...       ...
# 95  0.055  0.856  0.089    0.9355
# 96  0.047  0.785  0.168    0.9999
# 97  0.024  0.890  0.086    0.9869
# 98  0.030  0.826  0.144    0.9990
# 99  0.020  0.886  0.094    0.9869
#
# [100 rows x 4 columns]

# %%
scored_news = bitpush_news.join(content_scores_df, rsuffix='_right')
scored_news
# Out:
#                                                 Title  \
# 0          Why is Shiba Inu Up 200% in the Past Week?
# 1   What are the Most Promising Projects Building ...
# 2   Bitpush Research Paper: The Impact of Media an...
# 3            Why are there still no dApps on Cardano?
# 4   What is the NFT Project ‘Loot’ and How Valuabl...
# ..                                                ...
# 95  More Bad News Coming For XRP Proves Crypto Mar...
# 96  【Bitpush Interview】LinkedIn Co-Founder Eric Ly...
# 97  Institutional Investors Are Flooding Into Cryp...
# 98  What are the Best Blockchain Advancements of 2020
# 99  Decentralized Platform Metis Aims To Bring Web...
#
#                                               Content  \
# 0   In the past few weeks, the cryptocurrency mark...
# 1   With the recent launch of smart contracts, the...
# 2   Introduction:Since its inception of 2008, Bitc...
# 3   Now that Cardano has finally released smart co...
# 4   Loot is an NFT project that is taking the cryp...
# ..                                                ...
# 95  There are more bad news coming for XRP, follow...
# 96  The truth has become increasingly difficult to...
# 97  Crypto investments from institutional players ...
# 98  2020 has been a year of advancements in the bl...
# 99  MetisDAO, a new protocol aiming to drive the m...
#
#                                          Url        Time        Emotion  \
# 0   https://en.bitpush.news/articles/3660343  1633878038  偏0 甚至negative
# 1   https://en.bitpush.news/articles/3631214  1632387709              1
# 2   https://en.bitpush.news/articles/3627662  1632228330              1
# 3   https://en.bitpush.news/articles/3625850  1632153530             -1
# 4   https://en.bitpush.news/articles/3615932  1631648672              1
# ..                                       ...         ...            ...
# 95  https://en.bitpush.news/articles/2657945  1609902043              1
# 96  https://en.bitpush.news/articles/2652950  1609847942              1
# 97  https://en.bitpush.news/articles/2593443  1609168865              1
# 98  https://en.bitpush.news/articles/2592123  1609142063              1
# 99  https://en.bitpush.news/articles/2453118  1607513583              1
#
#       neg    neu    pos  compound
# 0   0.040  0.868  0.092    0.9826
# 1   0.007  0.853  0.140    0.9982
# 2   0.029  0.879  0.092    0.9986
# 3   0.038  0.853  0.109    0.9959
# 4   0.029  0.865  0.106    0.9919
# ..    ...    ...    ...       ...
# 95  0.055  0.856  0.089    0.9355
# 96  0.047  0.785  0.168    0.9999
# 97  0.024  0.890  0.086    0.9869
# 98  0.030  0.826  0.144    0.9990
# 99  0.020  0.886  0.094    0.9869
#
# [100 rows x 9 columns]

# %%
title = bitpush_news['Title']
title = str(title).encode('utf-8')
title_scores = bitpush_news['Title'].apply(lambda content:vader.polarity_scores(content)).tolist()
title_scores_df = pd.DataFrame(title_scores)
title_scores_df
# Out:
#       neg    neu    pos  compound
# 0   0.000  1.000  0.000    0.0000
# 1   0.000  0.728  0.272    0.4576
# 2   0.000  1.000  0.000    0.0000
# 3   0.239  0.761  0.000   -0.2960
# 4   0.000  0.780  0.220    0.4767
# ..    ...    ...    ...       ...
# 95  0.296  0.704  0.000   -0.5849
# 96  0.000  0.796  0.204    0.3182
# 97  0.000  0.691  0.309    0.7783
# 98  0.000  0.625  0.375    0.6369
# 99  0.000  1.000  0.000    0.0000
#
# [100 rows x 4 columns]

# %%
scored_news = scored_news.join(title_scores_df, rsuffix='_right')
scored_news
# Out:
#                                                 Title  \
# 0          Why is Shiba Inu Up 200% in the Past Week?
# 1   What are the Most Promising Projects Building ...
# 2   Bitpush Research Paper: The Impact of Media an...
# 3            Why are there still no dApps on Cardano?
# 4   What is the NFT Project ‘Loot’ and How Valuabl...
# ..                                                ...
# 95  More Bad News Coming For XRP Proves Crypto Mar...
# 96  【Bitpush Interview】LinkedIn Co-Founder Eric Ly...
# 97  Institutional Investors Are Flooding Into Cryp...
# 98  What are the Best Blockchain Advancements of 2020
# 99  Decentralized Platform Metis Aims To Bring Web...
#
#                                               Content  \
# 0   In the past few weeks, the cryptocurrency mark...
# 1   With the recent launch of smart contracts, the...
# 2   Introduction:Since its inception of 2008, Bitc...
# 3   Now that Cardano has finally released smart co...
# 4   Loot is an NFT project that is taking the cryp...
# ..                                                ...
# 95  There are more bad news coming for XRP, follow...
# 96  The truth has become increasingly difficult to...
# 97  Crypto investments from institutional players ...
# 98  2020 has been a year of advancements in the bl...
# 99  MetisDAO, a new protocol aiming to drive the m...
#
#                                          Url        Time        Emotion  \
# 0   https://en.bitpush.news/articles/3660343  1633878038  偏0 甚至negative
# 1   https://en.bitpush.news/articles/3631214  1632387709              1
# 2   https://en.bitpush.news/articles/3627662  1632228330              1
# 3   https://en.bitpush.news/articles/3625850  1632153530             -1
# 4   https://en.bitpush.news/articles/3615932  1631648672              1
# ..                                       ...         ...            ...
# 95  https://en.bitpush.news/articles/2657945  1609902043              1
# 96  https://en.bitpush.news/articles/2652950  1609847942              1
# 97  https://en.bitpush.news/articles/2593443  1609168865              1
# 98  https://en.bitpush.news/articles/2592123  1609142063              1
# 99  https://en.bitpush.news/articles/2453118  1607513583              1
#
#       neg    neu    pos  compound  neg_right  neu_right  pos_right  \
# 0   0.040  0.868  0.092    0.9826      0.000      1.000      0.000
# 1   0.007  0.853  0.140    0.9982      0.000      0.728      0.272
# 2   0.029  0.879  0.092    0.9986      0.000      1.000      0.000
# 3   0.038  0.853  0.109    0.9959      0.239      0.761      0.000
# 4   0.029  0.865  0.106    0.9919      0.000      0.780      0.220
# ..    ...    ...    ...       ...        ...        ...        ...
# 95  0.055  0.856  0.089    0.9355      0.296      0.704      0.000
# 96  0.047  0.785  0.168    0.9999      0.000      0.796      0.204
# 97  0.024  0.890  0.086    0.9869      0.000      0.691      0.309
# 98  0.030  0.826  0.144    0.9990      0.000      0.625      0.375
# 99  0.020  0.886  0.094    0.9869      0.000      1.000      0.000
#
#     compound_right
# 0           0.0000
# 1           0.4576
# 2           0.0000
# 3          -0.2960
# 4           0.4767
# ..             ...
# 95         -0.5849
# 96          0.3182
# 97          0.7783
# 98          0.6369
# 99          0.0000
#
# [100 rows x 13 columns]

# %%
def get_status(df):
    if (df['compound_right'] < 0):
        df["Total Score"] = df["compound"] * 0.15 + df["compound_right"] * 0.85
        return df["Total Score"]
    elif (df['compound_right'] > 0):
        df["Total Score"] = df["compound"] * 0.85 + df["compound_right"] * 0.15
        return df["Total Score"]
    else:
        df["Total Score"] = df["compound"] * 0.5 + df["compound_right"] * 0.5
        return df["Total Score"]

scored_news["Total Score"] = scored_news.apply(get_status, axis = 1)

# %%
scored_news
# Out:
#                                                 Title  \
# 0          Why is Shiba Inu Up 200% in the Past Week?
# 1   What are the Most Promising Projects Building ...
# 2   Bitpush Research Paper: The Impact of Media an...
# 3            Why are there still no dApps on Cardano?
# 4   What is the NFT Project ‘Loot’ and How Valuabl...
# ..                                                ...
# 95  More Bad News Coming For XRP Proves Crypto Mar...
# 96  【Bitpush Interview】LinkedIn Co-Founder Eric Ly...
# 97  Institutional Investors Are Flooding Into Cryp...
# 98  What are the Best Blockchain Advancements of 2020
# 99  Decentralized Platform Metis Aims To Bring Web...
#
#                                               Content  \
# 0   In the past few weeks, the cryptocurrency mark...
# 1   With the recent launch of smart contracts, the...
# 2   Introduction:Since its inception of 2008, Bitc...
# 3   Now that Cardano has finally released smart co...
# 4   Loot is an NFT project that is taking the cryp...
# ..                                                ...
# 95  There are more bad news coming for XRP, follow...
# 96  The truth has become increasingly difficult to...
# 97  Crypto investments from institutional players ...
# 98  2020 has been a year of advancements in the bl...
# 99  MetisDAO, a new protocol aiming to drive the m...
#
#                                          Url        Time        Emotion  \
# 0   https://en.bitpush.news/articles/3660343  1633878038  偏0 甚至negative
# 1   https://en.bitpush.news/articles/3631214  1632387709              1
# 2   https://en.bitpush.news/articles/3627662  1632228330              1
# 3   https://en.bitpush.news/articles/3625850  1632153530             -1
# 4   https://en.bitpush.news/articles/3615932  1631648672              1
# ..                                       ...         ...            ...
# 95  https://en.bitpush.news/articles/2657945  1609902043              1
# 96  https://en.bitpush.news/articles/2652950  1609847942              1
# 97  https://en.bitpush.news/articles/2593443  1609168865              1
# 98  https://en.bitpush.news/articles/2592123  1609142063              1
# 99  https://en.bitpush.news/articles/2453118  1607513583              1
#
#       neg    neu    pos  compound  neg_right  neu_right  pos_right  \
# 0   0.040  0.868  0.092    0.9826      0.000      1.000      0.000
# 1   0.007  0.853  0.140    0.9982      0.000      0.728      0.272
# 2   0.029  0.879  0.092    0.9986      0.000      1.000      0.000
# 3   0.038  0.853  0.109    0.9959      0.239      0.761      0.000
# 4   0.029  0.865  0.106    0.9919      0.000      0.780      0.220
# ..    ...    ...    ...       ...        ...        ...        ...
# 95  0.055  0.856  0.089    0.9355      0.296      0.704      0.000
# 96  0.047  0.785  0.168    0.9999      0.000      0.796      0.204
# 97  0.024  0.890  0.086    0.9869      0.000      0.691      0.309
# 98  0.030  0.826  0.144    0.9990      0.000      0.625      0.375
# 99  0.020  0.886  0.094    0.9869      0.000      1.000      0.000
#
#     compound_right  Total Score
# 0           0.0000     0.491300
# 1           0.4576     0.917110
# 2           0.0000     0.499300
# 3          -0.2960    -0.102215
# 4           0.4767     0.914620
# ..             ...          ...
# 95         -0.5849    -0.356840
# 96          0.3182     0.897645
# 97          0.7783     0.955610
# 98          0.6369     0.944685
# 99          0.0000     0.493450
#
# [100 rows x 14 columns]

# %%
scored_news.to_csv("news_analysis.csv",index=False)

# %%
scored_news.to_json("news_analysis.json",orient='index')
