# %% [markdown]
# ## Download and import vader

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
nltk.downloader.download('vader_lexicon')
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/yidanzhang/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ## Import packages

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# ## Read all data from news.csv with head (已整理Title, Date, Time)
# ## TODO: 重新整理content

# %%
sample_list = ["Title", "Date", "Time", "Content"]
sample_data = pd.read_csv('news_updated.csv', usecols=sample_list).astype(str) 
sample_data.head()
# Out:
#                                                Title        Date      Time  \
# 0  Bitcoin price hits $34K as trader forecasts fr...  2021-07-24  15:46:15
# 1  Bitcoin price hints at 'megaphone' bottom patt...  2021-07-24  13:42:02
# 2  Just HODL! Bitcoin and Ethereum outperform ‘lo...  2021-07-24  01:05:00
# 3  Price analysis 7/23: BTC, ETH, BNB, ADA, XRP, ...  2021-07-23  18:26:09
# 4  Bitcoin payments for real estate gain traction...  2021-07-23  17:15:24
#
#                                              Content
# 0  <p>Bitcoin (<a href="https://cointelegraph.com...
# 1  <p>Bitcoin's (<a href="https://cointelegraph.c...
# 2  <p>In the past two decades, index and exchange...
# 3  <p>Bitcoin’s (<a href="https://cointelegraph.c...
# 4  <p>Crypto investors are betting big on real es...

# %% [markdown]
# ## Calculate Sentiment Scores

# %%
vader = SentimentIntensityAnalyzer()
content = sample_data['Content']
content = str(content).encode('utf-8')
scores = sample_data['Content'].apply(lambda content:vader.polarity_scores(content)).tolist()
scores_df = pd.DataFrame(scores)
scores_df.head()
# Out:
#    compound    neg    neu    pos
# 0    0.9811  0.011  0.903  0.085
# 1    0.8581  0.064  0.868  0.068
# 2    0.9961  0.031  0.841  0.128
# 3    0.9951  0.067  0.840  0.093
# 4    0.9966  0.012  0.905  0.083

# %% [markdown]
# ## Add scores to original data frame

# %%
scored_news = sample_data.join(scores_df, rsuffix='_right')
scored_news.head()
# Out:
#                                                Title        Date      Time  \
# 0  Bitcoin price hits $34K as trader forecasts fr...  2021-07-24  15:46:15
# 1  Bitcoin price hints at 'megaphone' bottom patt...  2021-07-24  13:42:02
# 2  Just HODL! Bitcoin and Ethereum outperform ‘lo...  2021-07-24  01:05:00
# 3  Price analysis 7/23: BTC, ETH, BNB, ADA, XRP, ...  2021-07-23  18:26:09
# 4  Bitcoin payments for real estate gain traction...  2021-07-23  17:15:24
#
#                                              Content  compound    neg    neu  \
# 0  <p>Bitcoin (<a href="https://cointelegraph.com...    0.9811  0.011  0.903
# 1  <p>Bitcoin's (<a href="https://cointelegraph.c...    0.8581  0.064  0.868
# 2  <p>In the past two decades, index and exchange...    0.9961  0.031  0.841
# 3  <p>Bitcoin’s (<a href="https://cointelegraph.c...    0.9951  0.067  0.840
# 4  <p>Crypto investors are betting big on real es...    0.9966  0.012  0.905
#
#      pos
# 0  0.085
# 1  0.068
# 2  0.128
# 3  0.093
# 4  0.083

# %%
group_scored_news = scored_news.groupby("Date")
mean_scored_news = group_scored_news.mean()
mean_scored_news = mean_scored_news.reset_index()

# %%
mean_scored_news.head()
# Out:
#          Date  compound       neg       neu      pos
# 0  2018-12-25 -0.047950  0.043500  0.918000  0.03850
# 999973  06:40:00   7172.5  1179375     0.07  2019-11-25
# 999974  06:41:00   7178.0   605823    -0.08  2019-11-25
# 999975  06:42:00   7170.0  1712344     0.11  2019-11-25
# 999976  06:43:00   7175.5  1331382    -0.08  2019-11-25
# 999977  06:44:00   7175.0  1066774     0.01  2019-11-25
# 999978  06:45:00   7173.5   546389     0.02  2019-11-25
# 999979  06:46:00   7160.0  1358328     0.19  2019-11-25
# 999980  06:47:00   7162.5   871256    -0.03  2019-11-25
# 999981  06:48:00   7150.5  1466978     0.17  2019-11-25
# 999982  06:49:00   7151.5  1974054    -0.01  2019-11-25
# 999983  06:50:00   7149.5  1846837     0.03  2019-11-25
# 999984  06:51:00   7142.0  2601903     0.10  2019-11-25
# 999985  06:52:00   7143.0  2838553    -0.01  2019-11-25
# 999986  06:53:00   7149.0   895696    -0.08  2019-11-25
# 999987  06:54:00   7153.0  1288210    -0.06  2019-11-25
# 999988  06:55:00   7165.0  2341424    -0.17  2019-11-25
# 999989  06:56:00   7153.5   869978     0.16  2019-11-25
# 999990  06:57:00   7160.5  1148346    -0.10  2019-11-25
# 999991  06:58:00   7158.5   865118     0.03  2019-11-25
# 999992  06:59:00   7166.0  1917611    -0.10  2019-11-25
# 999993  07:00:00   7168.0  2721113    -0.03  2019-11-25
# 999994  07:01:00   7191.5  4464360    -0.33  2019-11-25
# 999995  07:02:00   7184.0  2898102     0.10  2019-11-25
# 999996  07:03:00   7182.5   820481     0.02  2019-11-25
# 999997  07:04:00   7190.0  1975713    -0.10  2019-11-25
# 999998  07:05:00   7212.0  5689980    -0.31  2019-11-25
#
# [999999 rows x 5 columns]

# %%
volume_data = parsed_price_data[['Date', ' Volume']]
group_volume_data = volume_data.groupby("Date")
sum_volume = group_volume_data.sum()
sum_volume = sum_volume.reset_index()

# %%
sum_volume.head()
# Out:
#          Date     Volume
# 0  2017-12-31  454478678
# 1  2018-01-01  680516250
# 2  2018-01-02  944152848
# 3  2018-01-03  817351695
# 4  2018-01-04  698479219

# %%
parsed_circulating_data = pd.read_csv('total-bitcoins.csv')
parsed_circulating_data.head()
# Out:
#              Timestamp  total-bitcoins
# 0  2009-01-03 17:15:05            50.0
# 1  2009-01-14 12:25:25         22750.0
# 2  2009-01-18 11:33:45         45450.0
# 3  2009-01-22 18:27:35         68150.0
# 4  2009-01-25 17:15:02         90850.0

# %%
from datetime import datetime
parsed_circulating_data['Timestamp'] = [datetime.fromtimestamp(x) for x in parsed_price_data['Timestamp']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timestamp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-8fe2ec8a960e> in <module>
#       1 from datetime import datetime
# ----> 2 parsed_circulating_data['Timestamp'] = [datetime.fromtimestamp(x) for x in parsed_price_data['Timestamp']]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Timestamp'

# %% [markdown]
# ## 截取疫情前后两个时间段的数据 (news, volume, circulating)
# * 2019/01/01 - 2019/06/30 --> mask1
# * 2020/01/01 - 2020/06/30 --> mask2

# %% [markdown]
# ### 2019/01/01 - 2019/06/30

# %%
mean_scored_news['Date'] = pd.to_datetime(mean_scored_news['Date'])
mask1 = (mean_scored_news['Date'] >= '2019-1-1') & (mean_scored_news['Date'] <= '2019-6-30')
train_data1 = mean_scored_news.loc[mask1] #Index(['Date', 'compound', 'neg', 'neu', 'pos'], dtype='object')
train_data1.head()
# Out:
#          Date  compound       neg       neu       pos
# 7  2019-01-01 -0.284267  0.043500  0.924667  0.031667
# 8  2019-01-02  0.041388  0.043125  0.909750  0.047375
# 9  2019-01-03  0.375067  0.040667  0.888333  0.071500
# 10 2019-01-04  0.328850  0.039000  0.927500  0.033500
# 11 2019-01-05  0.331000  0.050500  0.893500  0.056000

# %%
sum_volume['Date'] = pd.to_datetime(sum_volume['Date'])
price_mask1 = (sum_volume['Date'] >= '2019-1-1') & (sum_volume['Date'] <= '2019-6-30')
train_volume_data1 = sum_volume.loc[price_mask1]
train_volume_data1
# Out:
#           Date       Volume
# 366 2019-01-01    979039368
# 367 2019-01-02   1097663564
# 368 2019-01-03    889059787
# 369 2019-01-04    923185106
# 370 2019-01-05    640874439
# 371 2019-01-06   1135382157
# 372 2019-01-07    983979089
# 373 2019-01-08   1299810701
# 374 2019-01-09   1300895254
# 375 2019-01-10   1288240535
# 376 2019-01-11    858668929
# 377 2019-01-12    528143513
# 378 2019-01-13    826889890
# 379 2019-01-14    894912891
# 380 2019-01-15    910891876
# 381 2019-01-16    878153114
# 382 2019-01-17    872234719
# 383 2019-01-18    624158867
# 384 2019-01-19    754614452
# 385 2019-01-20   1099003213
# 386 2019-01-21    730724684
# 387 2019-01-22   1160910545
# 388 2019-01-23    901105130
# 389 2019-01-24    700970415
# 390 2019-01-25    955722082
# 391 2019-01-26    660037436
# 392 2019-01-27   1470991649
# 393 2019-01-28   1160378784
# 394 2019-01-29    931328731
# 395 2019-01-30    784636623
# ..         ...          ...
# 517 2019-06-01   1404174300
# 518 2019-06-02   2867912919
# 519 2019-06-03   4704029679
# 520 2019-06-04   3974263254
# 521 2019-06-05   2955053871
# 522 2019-06-06   3174058633
# 523 2019-06-07   2582445828
# 524 2019-06-08   1660667052
# 525 2019-06-09   2913955463
# 526 2019-06-10   2529147987
# 527 2019-06-11   2639147081
# 528 2019-06-12   2463613180
# 529 2019-06-13   2301320266
# 530 2019-06-14   3388441448
# 531 2019-06-15   3933392950
# 532 2019-06-16   4989453734
# 533 2019-06-17   4539899575
# 534 2019-06-18   3681423430
# 535 2019-06-19   2267007959
# 536 2019-06-20   4288517995
# 537 2019-06-21   6593093134
# 538 2019-06-22   6685488213
# 539 2019-06-23   4989317719
# 540 2019-06-24   4526622114
# 541 2019-06-25   8567939759
# 542 2019-06-26  12637756895
# 543 2019-06-27  10877152270
# 544 2019-06-28   7822407616
# 545 2019-06-29   4882704544
# 546 2019-06-30   6366042556
#
# [181 rows x 2 columns]

# %%
parsed_circulating_data['Date'] = pd.to_datetime(parsed_circulating_data['Timestamp'])
circulating_mask1 = (parsed_circulating_data['Date'] >= '2019-1-1') & (parsed_circulating_data['Date'] <= '2019-6-30')
train_circulating_data1 = parsed_circulating_data.loc[price_mask1]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-59-266b73789214> in <module>
#       1 parsed_circulating_data['Date'] = pd.to_datetime(parsed_circulating_data['Timestamp'])
#       2 circulating_mask1 = (parsed_circulating_data['Date'] >= '2019-1-1') & (parsed_circulating_data['Date'] <= '2019-6-30')
# ----> 3 train_circulating_data1 = parsed_circulating_data.loc[price_mask1]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1867             return self._get_slice_axis(key, axis=axis)
#    1868         elif com.is_bool_indexer(key):
# -> 1869             return self._getbool_axis(key, axis=axis)
#    1870         elif is_list_like_indexer(key):
#    1871
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#    1513             axis = self.axis or 0
#    1514         labels = self.obj._get_axis(axis)
# -> 1515         key = check_bool_indexer(labels, key)
#    1516         inds, = key.nonzero()
#    1517         try:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexing.py in check_bool_indexer(ax, key)
#    2484         mask = isna(result._values)
#    2485         if mask.any():
# -> 2486             raise IndexingError('Unalignable boolean Series provided as '
#    2487                                 'indexer (index of the boolean Series and of '
#    2488                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match

# %% [markdown]
# ### 2020/01/01 - 2020/06/30

# %%
scored_news['Date'] = pd.to_datetime(scored_news['Date'])
mask2 = (scored_news['Date'] >= '2020-1-1') & (scored_news['Date'] <= '2020-6-30')
train_data2 = scored_news.loc[mask2]
train_data2
# Out:
#                                                   Title       Date      Time  \
# 3915  Survey Shows 42% of Investors Expect a $15K Bi... 2020-06-30  22:03:00
# 3916  3 Reasons Why Bitcoin Price Recorded Its Third... 2020-06-30  20:17:00
# 3917      Bitcoin Scam Exposes Thousands to Data Breach 2020-06-30  16:55:00
# 3918  An Israeli Blockchain Startup Claims It’s Inve... 2020-06-30  15:00:00
# 3919  Max Keiser: US Hash Rate War With Iran Can Sen... 2020-06-30  14:20:00
# 3920  Gold vs. Bitcoin: $2.8B Fake Bullion Scam High... 2020-06-30  10:13:00
# 3921  Bitcoin Price Bulls Pin Hopes on Descending Ch... 2020-06-30  07:43:00
# 3922  Bitcoin’s ROI Since 2015 Outperforms Five Majo... 2020-06-30  05:44:00
# 3923  Researchers Say New Lightning Network Attack C... 2020-06-29  22:38:00
# 3924  Bitcoin as a Tool to Fight Authoritarian Regim... 2020-06-29  22:18:00
# 3925  Researchers Say Ransomware Attacks on the Rise... 2020-06-29  21:04:00
# 3926  Price Analysis 6/29: BTC, ETH, XRP, BCH, BSV, ... 2020-06-29  19:33:00
# 3927  International Authorities Work Together to Tak... 2020-06-29  17:44:00
# 3928  Bitcoin Dormant Supply Metric Mirrors 2016 Run... 2020-06-29  16:00:00
# 3929  OKEx Announced The Listing of Compound DeFi Pr... 2020-06-29  15:25:00
# 3930  Beyond Bitcoin: How Advances in Blockchain Can... 2020-06-29  14:19:00
# 3931  Bitcoin Miners Done Selling? 5 Things to Know ... 2020-06-29  10:02:00
# 3932  Crypto Research Report Predicts $397K Bitcoin ... 2020-06-29  09:21:00
# 3933  Bitcoin Price Must Flip This Level Into Suppor... 2020-06-29  08:30:00
# 3934  Andreas Antonopoulos: Use DeFi Contracts for B... 2020-06-29  07:47:00
# 3935  Blockchain Can Provide the Right to Privacy Th... 2020-06-28  21:00:00
# 3936  New Bitcoin Price Model Suggests ‘Exponential’... 2020-06-28  20:32:00
# 3937  Top 5 Cryptocurrencies to Watch This Week: BTC... 2020-06-28  19:21:00
# 5915  Bitcoin Must Gain 13,800% in 2020 to Stop John... 2020-01-01  08:56:00
# 5916             Worst Bitcoin Price Prediction of 2019 2020-01-01  01:00:00
#
#       compound    neg    neu    pos
# 3915    0.0000  0.000  1.000  0.000
# 3916    0.6369  0.000  0.704  0.296
# 3917   -0.6369  0.510  0.490  0.000
# 3918    0.0000  0.000  1.000  0.000
# 3919   -0.5994  0.231  0.769  0.000
# 3920   -0.6369  0.415  0.427  0.159
# 3921    0.4215  0.000  0.781  0.219
# 3922    0.0000  0.000  1.000  0.000
# 3923   -0.2500  0.254  0.574  0.172
# 3924   -0.5719  0.343  0.657  0.000
# 3925   -0.4404  0.195  0.805  0.000
# 3926    0.0000  0.000  1.000  0.000
# 3927    0.0000  0.000  1.000  0.000
# 3928    0.0000  0.000  1.000  0.000
# 3929    0.0000  0.000  1.000  0.000
# 3930    0.4404  0.000  0.775  0.225
# 3931    0.0000  0.000  1.000  0.000
# 3932    0.0000  0.000  1.000  0.000
# 3933   -0.1531  0.253  0.588  0.159
# 3934    0.2023  0.000  0.816  0.184
# 3935    0.0000  0.000  1.000  0.000
# 3936    0.0000  0.000  1.000  0.000
# 3937    0.2023  0.000  0.847  0.153
# 3938    0.0000  0.000  1.000  0.000
# 3939    0.0000  0.000  1.000  0.000
# 3940    0.0000  0.000  1.000  0.000
# 3941    0.0000  0.000  1.000  0.000
# 3942    0.0000  0.000  1.000  0.000
# 3943    0.2500  0.115  0.710  0.175
# 3944   -0.7506  0.416  0.584  0.000
# ...        ...    ...    ...    ...
# 5887    0.0000  0.000  1.000  0.000
# 5888    0.0000  0.000  1.000  0.000
# 5889    0.0000  0.000  1.000  0.000
# 5890   -0.2732  0.160  0.840  0.000
# 5891    0.0000  0.000  1.000  0.000
# 5892    0.0000  0.000  1.000  0.000
# 5893    0.7269  0.000  0.534  0.466
# 5894    0.0000  0.000  1.000  0.000
# 5895    0.0000  0.000  1.000  0.000
# 5896    0.0000  0.000  1.000  0.000
# 5897    0.4404  0.000  0.580  0.420
# 5898    0.0000  0.000  1.000  0.000
# 5899   -0.0516  0.150  0.714  0.136
# 5900    0.0000  0.000  1.000  0.000
# 5901    0.0000  0.000  1.000  0.000
# 5902   -0.4939  0.298  0.595  0.107
# 5903    0.0000  0.000  1.000  0.000
# 5904    0.4019  0.000  0.816  0.184
# 5905    0.0000  0.000  1.000  0.000
# 5906    0.0000  0.000  1.000  0.000
# 5907    0.0000  0.000  1.000  0.000
# 5908    0.0000  0.000  1.000  0.000
# 5909    0.4005  0.000  0.817  0.183
# 5910   -0.5994  0.464  0.327  0.209
# 5911    0.8979  0.000  0.391  0.609
# 5912   -0.4019  0.197  0.803  0.000
# 5913    0.0000  0.000  1.000  0.000
# 5914    0.4939  0.000  0.588  0.412
# 5915    0.2960  0.133  0.663  0.205
# 5916   -0.6249  0.451  0.549  0.000
#
# [2002 rows x 7 columns]

# %%
parsed_price_data['Date'] = pd.to_datetime(parsed_price_data['Date'])
price_mask2 = (parsed_price_data['Date'] >= '2020-1-1') & (parsed_price_data['Date'] <= '2020-6-30')
